# %%
import sys, os
modules_path = os.path.abspath('../modules')
if modules_path not in sys.path:
    sys.path.append(modules_path)
    
from equilibrium import Equilibrium
from elements import Element
from sweep import ConcentrationSweep

import numpy as np
import matplotlib.pyplot as plt
from time import time

# %matplotlib inline
# %reload_ext autoreload
# %autoreload 2

# %%
# parameters (energies in kcal/mole)
a0, b0, c0 = -10, -8, -5
alpha = [a0, a0] 
beta = [b0, b0] 
gamma = [c0, c0] 

params = dict(alpha=alpha, beta=beta, gamma=gamma)

# %%
element = Element(Ns=12, params=params, ets=(0,1))
sweep = ConcentrationSweep(cmin=(0, 0), cmax=(1, 1), Nc=(15, 15))
occupancies = sweep.get_occupancies(element, cut_depth=1)

# %%
func = lambda p, y: p*(1-y)
fig = occupancies.plot_mapping(func, cmap=plt.cm.seismic)
#fig = occupancies.plot_overall_occupancy(species='Pnt', cmap=plt.cm.PiYG, mask=True)
#fig = occupancies.plot_overall_occupancy(species='total')

# %%
"""
LOGICAL OPERATORS:

AND - two positive factors that only form co-polymers
OR - two positive factors that self or co polymerize
XOR - two factors that self-polymerize but destabilize each other
NOT AND - two negative factors that only form co-polymers
NOT OR (NOT EITHER) - two negative factors that self or co polymerize

QUESTION:
Can we use cis regulatory syntax to transition between these?

eg switch from ETS dominant to polymerization dominant, play with spacing of ETS sites

can clustering sites turn an AND gate into an OR gate?


"""

# %%
fig = occupancies.plot_contours(species='Pnt', variable='Pnt', fixed=12, figsize=(2.5, 2.5))

# %%
_ = occupancies.show_model()

# %%
old = np.load('old_occ.npy')
np.allclose(occupancies.occupancies, old)
# Out:
# True

# %%
subprocess.
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-2-f771f430e8a8> in <module>()
# ----> 1 subprocess
#
# NameError: name 'subprocess' is not defined

# %%
cel = el.get_c_element()

# %%
import pickle

# %%
pickle.Pickler(cel)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-16-8ac0c737b395> in <module>()
# ----> 1 pickle.Pickler(cel)
#
# TypeError: file must have a 'write' attribute

# %%
pickle.dump(cel, open('test_pickle.txt', 'wb'))

# %%
cel_recovered = pickle.load( open( "test_pickle.txt", "rb" ) )

# %%
cel_recovered

# %%
cel

# %%
@staticmethod
    def from_python(element, concentrations, cut_depth=None):

# %%
from partitions import PartitionFunction, cPF

# %%
pf = cPF.from_python(element, sweep.concentrations, cut_depth=0)

# %%
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-13-7dffac0f4090> in <module>()
# ----> 1 pickle.dump(pf, open('test_pickle.txt', 'wb'))
#
# ~/Documents/grad_school/research/binding/modules/partitions.cpython-36m-darwin.so in partitions.cPF.__reduce_cython__()
#
# TypeError: self.Z,self.degeneracy,self.leaf_degeneracy,self.leaf_deltaG,self.leaf_parent_branch,self.leaf_weights,self.occupancies,self.root_weights,self.weights cannot be converted to a Python object for pickling

# %%
from array import array
from trees import cTree
import pickle

# %%
Ns = 5
Nc = (25, 25)
sweep = ConcentrationSweep(cmin=(0, 0), cmax=(10, 10), Nc=Nc)
element = Element(Ns, params=params)

# %%
C = array('d', sweep.concentrations.flatten())
tree = cTree(element.get_c_element(), np.product(sweep.Nc), C, 0)

# %%
pickle.dump(tree, open('tree_pickle.txt', 'wb'))

# %%
tree_recovered = pickle.load( open( "tree_pickle.txt", "rb" ) )

# %%
def hill(x, n=1):
    return (x**n)/(0.2+(x**n))

# %%
hill(0)
# Out:
# 0.0

# %%
hill(1)
# Out:
# 0.6666666666666666

# %%
hill(1000000)
# Out:
# 0.999999000001

# %%
x = np.arange(0, 1.1, .1)
y = np.arange(0, 1.1, .1)

# %%
fig, ax = plt.subplots()
ax.plot(x, hill(x, n=1))
ax.set_xlim(0, 1)
ax.set_ylim(0, 1)
# Out:
# (0, 1)

# %%
xx, yy = np.meshgrid(*2*(np.arange(0, 1.1, .1),))

# %%
fig, ax = plt.subplots()
ax.imshow(xx*(1-yy))
ax.invert_yaxis()
